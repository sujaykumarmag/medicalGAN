# %%
import os
from PIL import Image

# %%
normal_images = os.listdir("../data/train/NORMAL")

# %%
DATA_PATH = "../data/train/PNEUMONIA"
normal_images = os.listdir(DATA_PATH)
for i in normal_images:
    x = Image.open(DATA_PATH+"/"+i)
    print(x.size)
# Out:
# (1048, 736)
# (984, 672)
# (992, 712)
# (1224, 888)
# (864, 480)
# (944, 584)
# (1816, 1110)
# (1408, 1024)
# (1200, 552)
# (1336, 1256)
# (1400, 1040)
# (1016, 608)
# (1360, 936)
# (1576, 1056)
# (850, 560)
# (1186, 866)
# (976, 600)
# (872, 528)
# (1264, 920)
# (1368, 912)
# (1192, 712)
# (936, 576)
# (1224, 656)
# (1240, 728)
# (976, 560)
# (1064, 632)
# (384, 127)
# (1136, 1008)
# (1184, 808)
# (1096, 624)
# (1008, 608)
# (1302, 867)
# (1206, 848)
# (1624, 1288)
# (1376, 1024)
# (1280, 784)
# (1384, 1088)
# (888, 536)
# (1176, 784)
# (1576, 1112)
# (1400, 896)
# (711, 537)
# (1208, 728)
# (1690, 1187)
# (1112, 872)
# (1368, 928)
# (1296, 832)
# (1504, 1056)
# (1080, 584)
# (1656, 1048)
# (1184, 704)
# (1526, 1052)
# (768, 552)
# (1164, 844)
# (1368, 840)
# (912, 704)
# (1096, 784)
# (1120, 808)
# (1312, 712)
# (1448, 888)
# (1256, 960)
# (952, 800)
# (1024, 824)
# (1440, 1112)
# (1287, 653)
# (1232, 880)
# (1160, 960)
# (976, 720)
# (1112, 704)
# (936, 424)
# (888, 632)
# ...

# %%
os.makedirs(OUTPUT_PATH, exist_ok=True)
normal_images = os.listdir(DATA_PATH)
for i in normal_images:
    input_image_path = os.path.join(DATA_PATH, i)
    original_image = Image.open(input_image_path)
    resized_image = original_image.resize(TARGET_SIZE)
    output_image_path = os.path.join(OUTPUT_PATH, i)
    resized_image.save(output_image_path)
    print(f"Original size: {original_image.size}, Resized size: {resized_image.size}")
# Out:
# Original size: (2359, 2234), Resized size: (1240, 1104)
# Original size: (1422, 1067), Resized size: (1240, 1104)
# Original size: (1828, 1357), Resized size: (1240, 1104)
# Original size: (1854, 1495), Resized size: (1240, 1104)
# Original size: (2194, 1966), Resized size: (1240, 1104)
# Original size: (2172, 1963), Resized size: (1240, 1104)
# Original size: (1902, 1665), Resized size: (1240, 1104)
# Original size: (1284, 1086), Resized size: (1240, 1104)
# Original size: (1188, 885), Resized size: (1240, 1104)
# Original size: (1432, 1184), Resized size: (1240, 1104)
# Original size: (1442, 1152), Resized size: (1240, 1104)
# Original size: (1410, 1106), Resized size: (1240, 1104)
# Original size: (2373, 2663), Resized size: (1240, 1104)
# Original size: (1632, 1225), Resized size: (1240, 1104)
# Original size: (1426, 1049), Resized size: (1240, 1104)
# Original size: (1692, 1302), Resized size: (1240, 1104)
# Original size: (2172, 1615), Resized size: (1240, 1104)
# ...

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.data_dir = data_dir
        self.image_paths = os.listdir(data_dir)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(self.data_dir+img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image


data_dir = '../data/train/NORMAL_resized/'

# Define your transformations (resize, normalize, etc.)
transform = transforms.Compose([
    transforms.Resize((1240, 1104)),
    transforms.ToTensor(),
    # Add more transformations as needed
])

# Create an instance of your custom dataset
custom_dataset = CustomDataset(data_dir, transform)

# Create a DataLoader
batch_size = 32  # Adjust the batch size based on your needs
data_loader = DataLoader(dataset=custom_dataset, batch_size=batch_size, shuffle=True)

# %%
for batch in data_loader:
    print(batch)
# Out:
# tensor([[[[0.1686, 0.1490, 0.1373,  ..., 0.0235, 0.0510, 0.0667],
#           [0.1686, 0.1490, 0.1373,  ..., 0.0353, 0.0627, 0.0784],
#           [0.1686, 0.1529, 0.1412,  ..., 0.0510, 0.0745, 0.0902],
#           ...,
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.1686, 0.1490, 0.1373,  ..., 0.0235, 0.0510, 0.0667],
#           [0.1686, 0.1490, 0.1373,  ..., 0.0353, 0.0627, 0.0784],
#           [0.1686, 0.1529, 0.1412,  ..., 0.0510, 0.0745, 0.0902],
#           ...,
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [1.0000, 1.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.1686, 0.1490, 0.1373,  ..., 0.0235, 0.0510, 0.0667],
#           [0.1686, 0.1490, 0.1373,  ..., 0.0353, 0.0627, 0.0784],
# ...

# %%
batch.shape
# Out:
# torch.Size([12, 3, 1240, 1104])

# %%
import matplotlib.pyplot as plt
plt.subplot (2, 3, 1)
plt. tight_layout ()
plt. imshow(batch.detach()[0,0,:,:], cmap='gray_r', interpolation='none')
plt. title ("Generated Data") 
plt.xticks([])
plt. yticks ([])
plt.axis ('off')
plt. show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pytorch_lightning as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pytorch_lightning as pl
#
# ModuleNotFoundError: No module named 'pytorch_lightning'
